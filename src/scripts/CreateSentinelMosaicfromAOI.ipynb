# %%
import arcpy.management
from arcgis.gis import GIS
from arcgis.raster import ImageryLayer
from arcgis.raster.functions import apply


import requests
import zipfile
import os
import tempfile
import datetime
import time
import arcpy
import hashlib
import arcpy
# Out:
# C:\Users\rami8629\AppData\Roaming\Python\Python39\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %% [markdown]
# # Functions
# <font color="red">**CAUTION**: Modify the functions below only if you understand the consequences.</font>

# %%
def download_and_extract(year):
    # Download the zipped file
    url = f"https://sentinel.esa.int/documents/d/sentinel/sentinel-2a-acquisition-plans-{year}"
    response = requests.get(url)

    # Save the zipped file to a temporary directory
    temp_dir = tempfile.mkdtemp()
    zip_path = os.path.join(temp_dir, "sentinel.zip")
    with open(zip_path, "wb") as f:
        f.write(response.content)

    # Extract the zipped file
    with zipfile.ZipFile(zip_path, 'r') as zip_ref:
        zip_ref.extractall(temp_dir)

    return temp_dir
def calculate_size(cell_size, max_pixels):
    # Calculate the size in square meters
    size_sqm = (cell_size * max_pixels)**2

    # Convert the size to square kilometers
    size_sqkm = size_sqm / 1e6

    return size_sqkm
def create_tessellation(aoi, cell_size, max_pixels):

    # Create the tessellation
    tessellation = arcpy.GenerateTessellation_management(
        Output_Feature_Class=r"memory/tessellation",
        Extent=aoi,
        Shape_Type="SQUARE",
        Size =  f"{calculate_size(cell_size, max_pixels)} SquareKilometers"

    )

    # Initialize the list of extents
    extents = []

    # Assume tessellation is the output from the create_tessellation function
    with arcpy.da.SearchCursor(tessellation, ["SHAPE@"]) as cursor:
        for row in cursor:
            feature = row[0]
            extent = feature.extent

            # Add the extent to the list
            extents.append(f'{extent.XMin},{extent.YMin},{extent.XMax},{extent.YMax}')

    return tessellation


def parse_kml_files(directory, tessellation, start_date, end_date):
    # Initialize the list of acquisition dates
    acq_dates_extent = []
    kmlgdbs = []
    # Loop through the files in the directory
    for filename in os.listdir(directory):
        if filename.endswith(".kml"):
            # Extract the acquisition dates from the KML file name
            acq_start, acq_end = filename.split("_")[5:7]
            acq_start = datetime.datetime.strptime(acq_start, "%Y%m%dT%H%M%S")
            acq_end = datetime.datetime.strptime(acq_end.split(".")[0], "%Y%m%dT%H%M%S")
            # Check if the acquisition dates fall within the defined start and end dates
            if start_date <= acq_start <= end_date or start_date <= acq_end <= end_date:
                # Convert the KML to a Layer
                arcpy.env.workspace = directory

                arcpy.conversion.KMLToLayer(os.path.join(directory, filename), directory)

                # Loop through all the file geodatabases in the workspace
                gdb = [gdb for gdb in arcpy.ListWorkspaces('*', 'FileGDB') if gdb not in kmlgdbs][0]
                kmlgdbs.append(gdb)

                arcpy.env.workspace = gdb

                # Find the polygon feature class in the file geodatabase
                
                datasets = arcpy.ListDatasets(feature_type='feature')
                datasets = [''] + datasets if datasets is not None else []

                for ds in datasets:
                    for fc in arcpy.ListFeatureClasses(feature_dataset=ds):
                        if arcpy.Describe(fc).shapeType == "Polygon":
                            # Perform a spatial join with the input AOI
                            arcpy.analysis.SpatialJoin(
                                target_features=tessellation,
                                join_features=f"{ds}\\{fc}",
                                out_feature_class="join",
                                join_operation="JOIN_ONE_TO_MANY",
                                join_type="KEEP_ALL",
                                field_mapping=None,
                                match_option="INTERSECT",
                                search_radius=None,
                                distance_field_name="",
                                match_fields=None
                            )
                            # Open a search cursor on the in_memory output
                            with arcpy.da.SearchCursor("join", ["BeginTime", "EndTime", "SHAPE@"], "Join_Count = 1") as cursor:
                                for row in cursor:
                                    extent_start_date = row[0].split("T")[0]
                                    start_of_date_unix = int(time.mktime(datetime.datetime.strptime(extent_start_date, '%Y-%m-%d').timetuple())) * 1000
                                    extent_end_date = row[1].split("T")[0]
                                    end_of_date_unix = int(((time.mktime(datetime.datetime.strptime(extent_end_date, '%Y-%m-%d').timetuple())) * 1000) + (43200000*1.5))
                                    # Append the start date of the filtered features to the acq_dates list
                                    acq_dates_extent.append([f"{start_of_date_unix}, {end_of_date_unix}", f"{row[2].extent.XMin},{row[2].extent.YMin},{row[2].extent.XMax},{row[2].extent.YMax}"])
                                del cursor, row
                        arcpy.management.Delete("join")
                            
                arcpy.env.workspace = directory

    return acq_dates_extent

def download_image(username, password, acq_date, max_pixels, extent, output_dir):
    gis = GIS("https://www.arcgis.com", username, password)
    sentinel_item=gis.content.search('255af1ceee844d6da8ef8440c8f90d00', 'Imagery Layer', outside_org=True)[0]
    s2_layer = sentinel_item.layers[0]

    sentinel_AllBands = apply(s2_layer, 'None')

    # Convert the acquisition dates from Unix timestamps to the ddMMYYYY format
    acq_start, acq_end = acq_date.split(", ")
    acq_start = datetime.datetime.fromtimestamp(int(acq_start) / 1000).strftime("%d%m%Y")
    acq_end = datetime.datetime.fromtimestamp(int(acq_end) / 1000).strftime("%d%m%Y")

    # Generate a unique hash for the extent
    extent_hash = hashlib.md5(str(extent).encode()).hexdigest()
    
    out_file = f"Sentinel2_{acq_start}_{acq_end}_{extent_hash}.tif"

    if out_file in os.listdir(output_dir):
        return
    

    # Define the output filename
    out_file = f"Sentinel2_{acq_start}_{acq_end}_{extent_hash}.tif"
    print(out_file)
    # Export the image
    sentinel_AllBands.export_image(bbox=extent, 
                        save_folder=output_dir, 
                        save_file=out_file, 
                        image_sr=3857, 
                        bbox_sr=3857, 
                        size=[max_pixels, max_pixels],
                        time=acq_date,
                        f="image", 
                        export_format="tiff")
def process_raster_data(output_dir):
    with arcpy.EnvManager(outputCoordinateSystem='PROJCS["WGS_1984_Web_Mercator_Auxiliary_Sphere",GEOGCS["GCS_WGS_1984",DATUM["D_WGS_1984",SPHEROID["WGS_1984",6378137.0,298.257223563]],PRIMEM["Greenwich",0.0],UNIT["Degree",0.0174532925199433]],PROJECTION["Mercator_Auxiliary_Sphere"],PARAMETER["False_Easting",0.0],PARAMETER["False_Northing",0.0],PARAMETER["Central_Meridian",0.0],PARAMETER["Standard_Parallel_1",0.0],PARAMETER["Auxiliary_Sphere_Type",0.0],UNIT["Meter",1.0]]'):
        outgdb = os.path.join(output_dir, "sentinel2.gdb")
        arcpy.management.CreateFileGDB(output_dir, "sentinel2.gdb")

        arcpy.management.CreateMosaicDataset(
            in_workspace=outgdb,
            in_mosaicdataset_name="sentinel2",
            coordinate_system='PROJCS["WGS_1984_Web_Mercator_Auxiliary_Sphere",GEOGCS["GCS_WGS_1984",DATUM["D_WGS_1984",SPHEROID["WGS_1984",6378137.0,298.257223563]],PRIMEM["Greenwich",0.0],UNIT["Degree",0.0174532925199433]],PROJECTION["Mercator_Auxiliary_Sphere"],PARAMETER["False_Easting",0.0],PARAMETER["False_Northing",0.0],PARAMETER["Central_Meridian",0.0],PARAMETER["Standard_Parallel_1",0.0],PARAMETER["Auxiliary_Sphere_Type",0.0],UNIT["Meter",1.0]]',
            num_bands=None,
            pixel_type="",
            product_definition="",
            product_band_definitions=None
        )
        arcpy.management.AddRastersToMosaicDataset(
            in_mosaic_dataset=os.path.join(outgdb, "sentinel2"),
            raster_type="Raster Dataset",
            input_path=f"{output_dir}",
            update_cellsize_ranges="UPDATE_CELL_SIZES",
            update_boundary="UPDATE_BOUNDARY",
            update_overviews="UPDATE_OVERVIEWS",
            maximum_pyramid_levels=None,
            maximum_cell_size=0,
            minimum_dimension=1500,
            spatial_reference=None,
            filter="",
            sub_folder="SUBFOLDERS",
            duplicate_items_action="ALLOW_DUPLICATES",
            build_pyramids="BUILD_PYRAMIDS",
            calculate_statistics="CALCULATE_STATISTICS",
            build_thumbnails="BUILD_THUMBNAILS",
            operation_description="",
            force_spatial_reference="NO_FORCE_SPATIAL_REFERENCE",
            estimate_statistics="ESTIMATE_STATISTICS",
            aux_inputs=None,
            enable_pixel_cache="NO_PIXEL_CACHE",
        )
        
    arcpy.management.MakeRasterLayer(os.path.join(outgdb, "sentinel2"), "sentinel2")

    # Define the feature class
    fc = "sentinel2"

    # Add the "AquisitionDate" field
    arcpy.AddField_management(fc, "AquisitionDate", "DATE", field_alias="Aquisition Date")

    # Define the update cursor
    cursor = arcpy.da.UpdateCursor(fc, ["Name", "AquisitionDate"])
    for row in cursor:
        if "Sen" in row[0]:
            # Extract the date string from the field value
            date_str = row[0].split("_")[2]

            # Convert the date string to a date object
            date_obj = datetime.datetime.strptime(date_str, "%d%m%Y").date()

            # Update the "AquisitionDate" field
            row[1] = date_obj

            # Update the row
            cursor.updateRow(row)
    del cursor, row
    return os.path.join(outgdb, "sentinel2")

# %% [markdown]
# # Variables

# %%
# Define Area of Interest (AOI) and output directory
# Change the aoi to the path of the feature class or shapefile that represents the area of interest
aoi = r"E:\OneDrive - Esri\Demos & Blogs\ArcGIS Resources\GeoAi & Deep Learning\Demos\Biomass_Cantabria\Biomass_Cantabria.gdb\Cantabria_Boundaries_WGS1984_Pro"
# Change the output_dir to the directory where you want to save the downloaded images and the processed raster data
output_dir = r"E:\OneDrive - Esri\Demos & Blogs\ArcGIS Resources\GeoAi & Deep Learning\Demos\Biomass_Cantabria\Sentinel2_15Bands"
arcpy.env.overwriteOutput = True
#Input AGOL credentials
username = input("Enter your ArcGIS Online username: ")
password = input("Enter your ArcGIS Online password: ")

# Define the start and end dates
start_date = datetime.datetime(2023, 5, 1)
end_date = datetime.datetime(2023, 6, 30)

# Define the maximum number of pixels
pixel_size = 256

# %% [markdown]
# # Download and create mosaic
#
# **DISCLAIMER**: Running the following cell may take <font color="green">**minutes to hours to sometimes days**</font> depending on the size of your <font color="green">**Area of Interest (AOI)**</font> and the range of your <font color="green">**start and end dates**</font>. Please be patient and allow the process to complete.

# %%
years = list(range(start_date.year, end_date.year+1))

for year in years:
    temp_dir = download_and_extract(year)

tessellation = create_tessellation(aoi, 10, 256)

acq_dates_extent = parse_kml_files(temp_dir, tessellation, start_date, end_date)

# Convert inner lists to tuples and remove duplicates
unique_acq_dates_extent = list(set(tuple(x) for x in acq_dates_extent))

# Convert inner tuples back to lists
unique_acq_dates_extent = [list(x) for x in unique_acq_dates_extent]

# Calculate the total number of images to be downloaded
total_images = len(unique_acq_dates_extent)
print(f"Total images to be downloaded: {total_images}")


# Loop through the list of acquisition dates and extents
image_count = 0
for acq_date_extent in unique_acq_dates_extent:
    download_image(username, password, acq_date_extent[0], 256, acq_date_extent[1], output_dir)
    image_count += 1
    print(f"Downloaded {image_count} of {total_images} images. {total_images - image_count} images left.")

# Process the raster data
out_mosaic = process_raster_data(output_dir)

print(f"Processed raster data saved to {out_mosaic}")
# Out:
# Total images to be downloaded: 39150
# Sentinel2_07062023_07062023_890bf9c31e8f6d6e3ac39281f3812313.tif
# Downloaded 1 of 39150 images. 39149 images left.
# Sentinel2_10072023_10072023_b62e678f6b99a814d7afb30453000285.tif
# Downloaded 2 of 39150 images. 39148 images left.
# Sentinel2_21042023_21042023_7c5ca6507d85576b20f5acf8a46e7641.tif
# Downloaded 3 of 39150 images. 39147 images left.
# Sentinel2_31052023_31052023_263f104f08d47a06098979cd4d48ecdc.tif
# Downloaded 4 of 39150 images. 39146 images left.
# Sentinel2_20062023_20062023_2414d308be892d1e5f03411c045cf883.tif
# Downloaded 5 of 39150 images. 39145 images left.
# Sentinel2_31052023_31052023_dfa508c31fcacd3adf07364711ebce6f.tif
# Downloaded 6 of 39150 images. 39144 images left.
# Sentinel2_11052023_11052023_d38517b4a2c5045704f236dab843c809.tif
# Downloaded 7 of 39150 images. 39143 images left.
# Sentinel2_21052023_21052023_e1c93af8cbe8ce438500ca4092b28591.tif
# Downloaded 8 of 39150 images. 39142 images left.
# Sentinel2_11052023_11052023_d7e44557b9de8c9197ed231cf56bc2f6.tif
# Downloaded 9 of 39150 images. 39141 images left.
# Sentinel2_21042023_21042023_940373ac47beb018f7ae2ea4ea0ae747.tif
# Downloaded 10 of 39150 images. 39140 images left.
# Sentinel2_21042023_21042023_0ec12774b7d402608ca63cbed1e72eae.tif
# Downloaded 11 of 39150 images. 39139 images left.
# Sentinel2_11052023_11052023_c998e0d021e162a2c415165ef3bd0bbb.tif
# Downloaded 12 of 39150 images. 39138 images left.
# Sentinel2_21042023_21042023_0eee4351f79cc174bca623687e8fb0d6.tif
# Downloaded 13 of 39150 images. 39137 images left.
# Sentinel2_31052023_31052023_9d644d3aa7716034ac4865b271b41109.tif
# Downloaded 14 of 39150 images. 39136 images left.
# Sentinel2_20062023_20062023_04b41a75dcf3f608e6c729779cea9fc6.tif
# Downloaded 15 of 39150 images. 39135 images left.
# Sentinel2_30062023_30062023_9bf67f5a92fd552b354fe588d7b856ef.tif
# Downloaded 209 of 39150 images. 38941 images left.
# Sentinel2_20062023_20062023_be8d665b38b49f7ed6c7fb9b01777a65.tif
# Downloaded 210 of 39150 images. 38940 images left.
# Sentinel2_10062023_10062023_1546c45761b22d5e121921c8bd32ec4e.tif
# Downloaded 211 of 39150 images. 38939 images left.
# Sentinel2_01052023_01052023_356ba2e3d04fb2f31e2e8d2ac4cdc104.tif
# Downloaded 212 of 39150 images. 38938 images left.
# Sentinel2_18052023_18052023_d973382ad1f7f7b51297c7845fef399d.tif
# Downloaded 213 of 39150 images. 38937 images left.
# Sentinel2_10062023_10062023_f3de294e350daa4cd2dd8741afb53026.tif
# Downloaded 214 of 39150 images. 38936 images left.
# Sentinel2_21042023_21042023_d7639a0812cff96fb26cd0607adb178d.tif
# Downloaded 215 of 39150 images. 38935 images left.
# Sentinel2_21052023_21052023_d4e070c8b24be6e3be1813cff02d46f8.tif
# Downloaded 216 of 39150 images. 38934 images left.
# Sentinel2_20062023_20062023_2bba4c2b3f7b1cccc7d42f165b7107af.tif
# Downloaded 217 of 39150 images. 38933 images left.
# Sentinel2_30062023_30062023_8ca08831a6a09fa5c23c410cfac40c31.tif
# Downloaded 218 of 39150 images. 38932 images left.
# Sentinel2_11052023_11052023_3eca9578902a3c92e443c04f5dcaff3c.tif
# Downloaded 219 of 39150 images. 38931 images left.
# Sentinel2_21042023_21042023_0f046c1fb43c314978e72376c51fa72e.tif
# Downloaded 220 of 39150 images. 38930 images left.
# Sentinel2_10072023_10072023_844e03eed19bae565b8fd6fca058d14a.tif
# Downloaded 221 of 39150 images. 38929 images left.
# Sentinel2_10062023_10062023_ff10ffa1b876ba6d1e4d733d687533a6.tif
# Downloaded 222 of 39150 images. 38928 images left.
# Sentinel2_01052023_01052023_2eae6e19ca492fa681dc6ca49d51f15c.tif
# Downloaded 223 of 39150 images. 38927 images left.
# Sentinel2_01052023_01052023_18481001e6fedfc36509ab30a36b246d.tif
# Downloaded 224 of 39150 images. 38926 images left.
# Sentinel2_21052023_21052023_45d765c4160928ea3d5865b0ef00c008.tif
# Downloaded 225 of 39150 images. 38925 images left.
# Sentinel2_30062023_30062023_cf5e62b4635ae41dbafaec72ecce450f.tif
# Downloaded 226 of 39150 images. 38924 images left.
# Sentinel2_11052023_11052023_24794d24a8396e5384fd478624d7297c.tif
# Downloaded 227 of 39150 images. 38923 images left.
# Sentinel2_31052023_31052023_ba5e47c831f87be9c656e4b5e00119dd.tif
# Downloaded 228 of 39150 images. 38922 images left.
# Sentinel2_27062023_27062023_318656a0eb259187464e6cac31002135.tif
# Downloaded 229 of 39150 images. 38921 images left.
# Sentinel2_08052023_08052023_8fb524560c8347c6e4bbb2d8a470dcc0.tif
# Downloaded 230 of 39150 images. 38920 images left.
# Sentinel2_10062023_10062023_b26b47af80f2a93d5c1304484ab56559.tif
# Downloaded 231 of 39150 images. 38919 images left.
# Sentinel2_30062023_30062023_485cee2f6fa72bff0f32afead224cff7.tif
# Downloaded 232 of 39150 images. 38918 images left.
# Sentinel2_21042023_21042023_0f7a9c36b03ff455cd18abac0b79eb18.tif
# Downloaded 281 of 39150 images. 38869 images left.
# Sentinel2_21042023_21042023_2c2b05c960c7b8b46f40b4129d789e93.tif
# Downloaded 282 of 39150 images. 38868 images left.
# Sentinel2_30062023_30062023_861ade0648a3840897b5ee8ba70287d2.tif
# Downloaded 283 of 39150 images. 38867 images left.
# Sentinel2_07062023_07062023_86273592eb64f187d859c339acba86a5.tif
# Downloaded 284 of 39150 images. 38866 images left.
# Sentinel2_17072023_17072023_b4c0f93ea1b208712c976e2f3138988b.tif
# Downloaded 285 of 39150 images. 38865 images left.
# Sentinel2_21042023_21042023_f01fa878efc97d0c75373dd97f36b6c2.tif
# Downloaded 286 of 39150 images. 38864 images left.
# Sentinel2_20062023_20062023_620e62082d5c137fe5a8989271ddf2b1.tif
# Downloaded 287 of 39150 images. 38863 images left.
# Sentinel2_21042023_21042023_8a9ce37ebd5026f4e1f44c0c7022ebd7.tif
# Downloaded 288 of 39150 images. 38862 images left.
# Sentinel2_21042023_21042023_9baff6b3f380b4a5a44dac1315ca9b0f.tif
# Downloaded 289 of 39150 images. 38861 images left.
# Sentinel2_18052023_18052023_0257b744f501980f103f6aefb5030c10.tif
# Downloaded 290 of 39150 images. 38860 images left.
# Sentinel2_20062023_20062023_a11795af480d09b2e8a1cc71bbee2671.tif
# Downloaded 291 of 39150 images. 38859 images left.
# Sentinel2_17072023_17072023_867d895efe317841819db30dba72a795.tif
# Downloaded 292 of 39150 images. 38858 images left.
# Sentinel2_17072023_17072023_f06df7cc3cd0deed56acf56e08824f5c.tif
# Downloaded 293 of 39150 images. 38857 images left.
# Sentinel2_11052023_11052023_6669c24ee2fb7fc052a8762c65e9871c.tif
# Downloaded 294 of 39150 images. 38856 images left.
# Sentinel2_17072023_17072023_0e1fa286e42c267c4ce078ac3c9f0841.tif
# Downloaded 295 of 39150 images. 38855 images left.
# Sentinel2_10072023_10072023_efb2c7e036c3f4369e7dd171844fc21b.tif
# Downloaded 296 of 39150 images. 38854 images left.
# Sentinel2_01052023_01052023_938cbf40ff133036f5565633b3868798.tif
# Downloaded 297 of 39150 images. 38853 images left.
# Sentinel2_31052023_31052023_e1544c8f31b543b0cc46f68730d48ad4.tif
# Downloaded 298 of 39150 images. 38852 images left.
# Sentinel2_31052023_31052023_65fa1936447f948b38811b12a0c2f728.tif
# Downloaded 299 of 39150 images. 38851 images left.
# Sentinel2_20062023_20062023_ab0fb458016fa1fc3e203b08c675af2c.tif
# Downloaded 300 of 39150 images. 38850 images left.
# Sentinel2_31052023_31052023_0daa07f106c7e99a226cf4f56fdcb114.tif
# Downloaded 301 of 39150 images. 38849 images left.
# Sentinel2_21052023_21052023_8278e795348382f2f83c7bc4a69e752a.tif
# Downloaded 302 of 39150 images. 38848 images left.
# Sentinel2_10062023_10062023_d925006c5d007e3b3b0ca5ece6e17ffd.tif
# Downloaded 303 of 39150 images. 38847 images left.
# Sentinel2_11052023_11052023_b4137102c2e7d1c3affc80e5c75e9709.tif
# Downloaded 304 of 39150 images. 38846 images left.
# Sentinel2_01052023_01052023_7a68e803a32281a06fb4907583cdc42f.tif
# Downloaded 354 of 39150 images. 38796 images left.
# Sentinel2_24042023_24042023_e087b52f048dfe827503158f2b294f6e.tif
# Downloaded 355 of 39150 images. 38795 images left.
# Sentinel2_11052023_11052023_1345802965225b17a3467afb9cb2c886.tif
# Downloaded 356 of 39150 images. 38794 images left.
# Sentinel2_18052023_18052023_985c262d27817e85ba82857c8070ca29.tif
# Downloaded 357 of 39150 images. 38793 images left.
# Sentinel2_20062023_20062023_6132825968a8149556aa83540c71c63d.tif
# Downloaded 358 of 39150 images. 38792 images left.
# Sentinel2_11052023_11052023_fc60f6edbf0c383858f50896c476f5e4.tif
# Downloaded 359 of 39150 images. 38791 images left.
# Sentinel2_28042023_28042023_e1c93af8cbe8ce438500ca4092b28591.tif
# Downloaded 360 of 39150 images. 38790 images left.
# Sentinel2_20062023_20062023_65aeeb56396a28a8bc04339439d7bd2e.tif
# Downloaded 361 of 39150 images. 38789 images left.
# Sentinel2_20062023_20062023_4d463e4005db6b15264a4a64146ab878.tif
# Downloaded 362 of 39150 images. 38788 images left.
# Sentinel2_11052023_11052023_7d9165703e6485191eb895172c022865.tif
# Downloaded 363 of 39150 images. 38787 images left.
# Sentinel2_10062023_10062023_dba07c801c8ea114e2e4b637ad948c1b.tif
# Downloaded 364 of 39150 images. 38786 images left.
# Sentinel2_01052023_01052023_e40fce308b1ca07ba09a5012177d3e71.tif
# Downloaded 365 of 39150 images. 38785 images left.
# Sentinel2_17062023_17062023_ccd7d7a66b5f695714cd85bfc9193980.tif
# Downloaded 366 of 39150 images. 38784 images left.
# Sentinel2_28042023_28042023_fcc8c52cdb57674e2d03b4399d2f0c90.tif
# Downloaded 367 of 39150 images. 38783 images left.
# Sentinel2_10072023_10072023_6b5230cf999aa3e8732919100eb4aeab.tif
# Downloaded 368 of 39150 images. 38782 images left.
# Sentinel2_11052023_11052023_bf8ebaf877d2f8c431f870a25005f94c.tif
# Downloaded 369 of 39150 images. 38781 images left.
# Sentinel2_31052023_31052023_bb1a109c6620a4d298e5aa4b2fab3920.tif
# Downloaded 370 of 39150 images. 38780 images left.
# Sentinel2_20062023_20062023_63883da3bc34981615604f1a602f2b90.tif
# Downloaded 371 of 39150 images. 38779 images left.
# Sentinel2_31052023_31052023_4c3737c5f05544d9205f352a9ee9f89a.tif
# Downloaded 372 of 39150 images. 38778 images left.
# Sentinel2_10062023_10062023_dbba22ceae59ad9acc4c4652bcca4224.tif
# Downloaded 373 of 39150 images. 38777 images left.
# Sentinel2_20062023_20062023_a7df1ddfa2b122e4e14dc670a781d4ea.tif
# Downloaded 374 of 39150 images. 38776 images left.
# Sentinel2_20062023_20062023_efe435e20c815a29d415c9d5d6a92ac1.tif
# Downloaded 375 of 39150 images. 38775 images left.
# Sentinel2_31052023_31052023_bc40d09fe9d741576b2fbc06a791c3ff.tif
# Downloaded 376 of 39150 images. 38774 images left.
# Sentinel2_28042023_28042023_130e7986376f790b5de3280aa073f7b9.tif
# Downloaded 377 of 39150 images. 38773 images left.
# Sentinel2_31052023_31052023_b4d7c17308269e7feb4ff5efd3864b79.tif
# Downloaded 378 of 39150 images. 38772 images left.
# Sentinel2_10062023_10062023_295320f3d677c5c52b446a556fbb9218.tif
# Downloaded 379 of 39150 images. 38771 images left.
# Sentinel2_10062023_10062023_226cc04683b4aeec4a64306471c7b049.tif
# Downloaded 380 of 39150 images. 38770 images left.
# Sentinel2_31052023_31052023_e612c6075b0afa58023aac14b470aa96.tif
# Downloaded 381 of 39150 images. 38769 images left.
# Sentinel2_10072023_10072023_112ecdb03e54c30dfc9d16978eb68ed8.tif
# Downloaded 382 of 39150 images. 38768 images left.
# Sentinel2_18052023_18052023_4c84a321da7fa8ed030da1756cf65b4c.tif
# Downloaded 383 of 39150 images. 38767 images left.
# Sentinel2_21042023_21042023_ea8c4db30336829c854596d9af1baed3.tif
# Downloaded 384 of 39150 images. 38766 images left.
# Sentinel2_21052023_21052023_5df61803c1c5aa12e3256c10b8d1b532.tif
# Downloaded 385 of 39150 images. 38765 images left.
# Sentinel2_30062023_30062023_dcb6defa41e9ef2408e0862e7ba82ec5.tif
# Downloaded 386 of 39150 images. 38764 images left.
# Sentinel2_27062023_27062023_0b528e53f630f90e7c734f5136217fc9.tif
# Downloaded 387 of 39150 images. 38763 images left.
# Sentinel2_01052023_01052023_854cd1b9ff9d4ac44e2d43ddbaa6ab02.tif
# Downloaded 388 of 39150 images. 38762 images left.
# Sentinel2_21042023_21042023_71d3bcaf4b41b69ec9beece026a17ed7.tif
# Downloaded 389 of 39150 images. 38761 images left.
# Sentinel2_11052023_11052023_313982da36a877b726344149cad576aa.tif
# Downloaded 390 of 39150 images. 38760 images left.
# Sentinel2_10072023_10072023_b4ecfd47c8df066d2d19ad32456a2637.tif
# Downloaded 391 of 39150 images. 38759 images left.
# Sentinel2_01052023_01052023_84c6267ae0b41402a61a3e0e93398f7e.tif
# Downloaded 392 of 39150 images. 38758 images left.
# Sentinel2_21052023_21052023_1e0d98f729e3fe9f470f920b083347b1.tif
# Downloaded 393 of 39150 images. 38757 images left.
# Sentinel2_30062023_30062023_f74f7be8fe62a486172d1da070bd2311.tif
# Downloaded 394 of 39150 images. 38756 images left.
# Sentinel2_11052023_11052023_de32c42bad6aeb7bc1fd630d0e71f8ed.tif
# Downloaded 395 of 39150 images. 38755 images left.
# Sentinel2_31052023_31052023_a37d77877468e2048e1488f99ddb29f6.tif
# Downloaded 396 of 39150 images. 38754 images left.
# Sentinel2_11052023_11052023_1072d553607a480ed59ec31795e7918c.tif
# Downloaded 397 of 39150 images. 38753 images left.
# Sentinel2_10062023_10062023_ee40218a18591873b32a387da47c6d8e.tif
# Downloaded 398 of 39150 images. 38752 images left.
# Sentinel2_31052023_31052023_a07121f9e9207d7a6062eff0b3a03aa7.tif
# Downloaded 399 of 39150 images. 38751 images left.
# Sentinel2_01052023_01052023_88ed73d6c8d3f0faedb7e6e9305f14cd.tif
# Downloaded 400 of 39150 images. 38750 images left.
# Sentinel2_24042023_24042023_2513975228065df305453c01205f2600.tif
# Downloaded 401 of 39150 images. 38749 images left.
# Sentinel2_20062023_20062023_45745e3f7685fa3e4423f8cbc63cdde3.tif
# Downloaded 402 of 39150 images. 38748 images left.
# Sentinel2_30062023_30062023_604842866472b53c5afaf3d6e4c28cd8.tif
# Downloaded 403 of 39150 images. 38747 images left.
# Sentinel2_20062023_20062023_b215ca8f49cc3243857ee62d09793acf.tif
# Downloaded 404 of 39150 images. 38746 images left.
# Sentinel2_01052023_01052023_730e6f47037b232d945855fc9f5c5f6c.tif
# Downloaded 405 of 39150 images. 38745 images left.
# Sentinel2_21052023_21052023_17a58a3b337ab6678a88b4d87dec11e5.tif
# Downloaded 406 of 39150 images. 38744 images left.
# Sentinel2_21052023_21052023_ea79afbd58741a7f744a0f4d4ad6d7ad.tif
# Downloaded 407 of 39150 images. 38743 images left.
# Sentinel2_20062023_20062023_8b70862d70f7b7eef23bedc6bafc698f.tif
# Downloaded 408 of 39150 images. 38742 images left.
# Sentinel2_10072023_10072023_3af7ab2b2af43bd5688f960e7f242172.tif
# Downloaded 409 of 39150 images. 38741 images left.
# Sentinel2_11052023_11052023_46a1b326b5a29dabbee20363c40c298f.tif
# Downloaded 410 of 39150 images. 38740 images left.
# Sentinel2_28052023_28052023_11930a3fbd8a1628e537436022af3190.tif
# Downloaded 411 of 39150 images. 38739 images left.
# Sentinel2_20062023_20062023_d6a312c231a052749152329db6aa6784.tif
# Downloaded 412 of 39150 images. 38738 images left.
# Sentinel2_21052023_21052023_c3cf95c76a144ab217bf348ae6475f51.tif
# Downloaded 413 of 39150 images. 38737 images left.
# Sentinel2_21052023_21052023_c3c5523f8a3c17c1d1137a5bd9efbebd.tif
# Downloaded 414 of 39150 images. 38736 images left.
# Sentinel2_28042023_28042023_35d5b8e7d1eb65b8e3bbd2d1d71018dd.tif
# Downloaded 415 of 39150 images. 38735 images left.
# ...
# Sentinel2_10072023_10072023_697ee0a2f31cb502567906cf0f6a914f.tif
# Downloaded 529 of 39150 images. 38621 images left.
# Sentinel2_30062023_30062023_7f884242183baa4e89cc7bd97bcf2723.tif
# Downloaded 530 of 39150 images. 38620 images left.
# Sentinel2_20062023_20062023_683341f5ebbf5c5531d6b5316220b89d.tif
# Downloaded 531 of 39150 images. 38619 images left.
# Sentinel2_10062023_10062023_faac905dfd4485f171fab19004900cd6.tif
# Downloaded 532 of 39150 images. 38618 images left.
# Sentinel2_10072023_10072023_e7f16f56cb8a1d63668a541f39624e87.tif
# Downloaded 533 of 39150 images. 38617 images left.
# Sentinel2_08052023_08052023_7ef93d77b0834641467ec371c648c24f.tif
# Downloaded 534 of 39150 images. 38616 images left.
# Sentinel2_07072023_07072023_f5141e2adb40611dad6f8fe18f47aa8f.tif
# Downloaded 535 of 39150 images. 38615 images left.
# Sentinel2_10062023_10062023_9e4cedf0ad3f565ff8f00391370b46a7.tif
# Downloaded 536 of 39150 images. 38614 images left.
# Sentinel2_17062023_17062023_0cfc7fc8b25f579d618850bd79751643.tif
# Downloaded 537 of 39150 images. 38613 images left.
# Sentinel2_21052023_21052023_f8d2a8af889e079cb5c4e98cd675c03c.tif
# Downloaded 538 of 39150 images. 38612 images left.
# Sentinel2_01052023_01052023_ecffe1efa9ba102cc350f13e04905cc1.tif
# Downloaded 539 of 39150 images. 38611 images left.
# Sentinel2_21052023_21052023_350c2099f589c39654733863bbacdcb5.tif
# Downloaded 540 of 39150 images. 38610 images left.
# Sentinel2_07072023_07072023_4582b63b10e4abf8108bd9cd49288eb3.tif
# Downloaded 541 of 39150 images. 38609 images left.
# Sentinel2_30062023_30062023_69213188bcd084ecfb59ecbaa40c3a8f.tif
# Downloaded 542 of 39150 images. 38608 images left.
# Sentinel2_21042023_21042023_4b5ba651958b90759ec5ad477a70e2d4.tif
# Downloaded 543 of 39150 images. 38607 images left.
# Sentinel2_21042023_21042023_924186f4b861db997cedd3c0ff73830f.tif
# Downloaded 544 of 39150 images. 38606 images left.
# Sentinel2_31052023_31052023_55d32d227aa89204ee375ece070b2322.tif
# Downloaded 545 of 39150 images. 38605 images left.
# Sentinel2_31052023_31052023_74f4f8f7b2042c73460edc953469e49c.tif
# Downloaded 546 of 39150 images. 38604 images left.
# Sentinel2_21052023_21052023_6a62d935e6e9a8c3679061e61ab1368b.tif
# Downloaded 547 of 39150 images. 38603 images left.
# Sentinel2_31052023_31052023_448e58b154cc27c62f4bf4f852bb50b6.tif
# Downloaded 548 of 39150 images. 38602 images left.
# Sentinel2_21042023_21042023_e07a2f4ef0a9d299ed2f42527762e22b.tif
# Downloaded 549 of 39150 images. 38601 images left.
# Sentinel2_04052023_04052023_5b359795b5c2585e7eb2e0491a8b2a6d.tif
# Downloaded 550 of 39150 images. 38600 images left.
# Sentinel2_21042023_21042023_ebb31cfaa86b2e9a14e2a14ef2ca373a.tif
# Downloaded 551 of 39150 images. 38599 images left.
# Sentinel2_21052023_21052023_9891e3283dc4e60127a4c85a693ce5f0.tif
# Downloaded 552 of 39150 images. 38598 images left.
# Sentinel2_01052023_01052023_406c6defef9535c4dbe816d6a16f10cc.tif
# Downloaded 553 of 39150 images. 38597 images left.
# Sentinel2_31052023_31052023_8befe4cc36ab047fa720eb2329faa050.tif
# Downloaded 554 of 39150 images. 38596 images left.
# Sentinel2_21052023_21052023_e1641beed2d67926ed46e49b66d2ef5c.tif
# Downloaded 555 of 39150 images. 38595 images left.
# Downloaded 556 of 39150 images. 38594 images left.
# Sentinel2_10062023_10062023_1ee2f3c894157fd3013d00813eb6e606.tif
# Downloaded 557 of 39150 images. 38593 images left.
# Sentinel2_01052023_01052023_929d175355604d951a815f5633ccc5c4.tif
# Downloaded 558 of 39150 images. 38592 images left.
# Sentinel2_10062023_10062023_4e75912ffa80a202df26e5604be4ca24.tif
# Downloaded 559 of 39150 images. 38591 images left.
# Sentinel2_31052023_31052023_d7df3371aa3a6011a1548014e427e28c.tif
# Downloaded 560 of 39150 images. 38590 images left.
# Sentinel2_10062023_10062023_021eb6a5a71c565f46be850bc5642079.tif
# Downloaded 561 of 39150 images. 38589 images left.
# Sentinel2_30062023_30062023_33ab8ec1118f581a2866c538fb10818a.tif
# Downloaded 562 of 39150 images. 38588 images left.
# Sentinel2_11052023_11052023_dcb6defa41e9ef2408e0862e7ba82ec5.tif
# Downloaded 563 of 39150 images. 38587 images left.
# Sentinel2_07072023_07072023_13bd402f7d8a718749e3cb2a15a43847.tif
# Downloaded 564 of 39150 images. 38586 images left.
# Sentinel2_10062023_10062023_0c6e51d2a3cf5bb2162c4e2281d8e45e.tif
# Downloaded 565 of 39150 images. 38585 images left.
# Sentinel2_30062023_30062023_212383ad0d01d38eeca8343be5d31c38.tif
# Downloaded 566 of 39150 images. 38584 images left.
# Sentinel2_30062023_30062023_2b0240520103446282ae6a8b77f72762.tif
# Downloaded 567 of 39150 images. 38583 images left.
# Sentinel2_21042023_21042023_9962cdd9a76d35d4ee806034f2ac9173.tif
# Downloaded 568 of 39150 images. 38582 images left.
# Sentinel2_10062023_10062023_60e5d0a0ada894c6c743a58e34dc3563.tif
# Downloaded 569 of 39150 images. 38581 images left.
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# c:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     173         try:
# --> 174             conn = connection.create_connection(
#     175                 (self._dns_host, self.port), self.timeout, **extra_kw
#
# c:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      71
# ---> 72     for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      73         af, socktype, proto, canonname, sa = res
#
# c:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     953     addrlist = []
# --> 954     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     955         af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno 11001] getaddrinfo failed
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# c:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     713             # Make the request on the httplib connection object.
# --> 714             httplib_response = self._make_request(
#     715                 conn,
#
# c:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     402         try:
# --> 403             self._validate_conn(conn)
#     404         except (SocketTimeout, BaseSSLError) as e:
#
# c:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\urllib3\connectionpool.py in _validate_conn(self, conn)
#    1052         if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> 1053             conn.connect()
#    1054
#
# c:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\urllib3\connection.py in connect(self)
#     362         # Add certificate verification
# --> 363         self.sock = conn = self._new_conn()
#     364         hostname = self.host
#
# c:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     185         except SocketError as e:
# --> 186             raise NewConnectionError(
#     187                 self, "Failed to establish a new connection: %s" % e
#
# NewConnectionError: <urllib3.connection.HTTPSConnection object at 0x000001CB5BBA09A0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# c:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     485         try:
# --> 486             resp = conn.urlopen(
#     487                 method=request.method,
#
# c:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     825             )
# --> 826             return self.urlopen(
#     827                 method,
#
# c:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     825             )
# --> 826             return self.urlopen(
#     827                 method,
#
# c:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     825             )
# --> 826             return self.urlopen(
#     827                 method,
#
# c:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     825             )
# --> 826             return self.urlopen(
#     827                 method,
#
# c:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     825             )
# --> 826             return self.urlopen(
#     827                 method,
#
# c:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     797
# --> 798             retries = retries.increment(
#     799                 method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#
# c:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\urllib3\util\retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     591         if new_retry.is_exhausted():
# --> 592             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     593
#
# MaxRetryError: HTTPSConnectionPool(host='esriaiddev.maps.arcgis.com', port=443): Max retries exceeded with url: /sharing/rest/search (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000001CB5BBA09A0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# c:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\arcgis\gis\_impl\_con\_connection.py in post(self, path, params, files, **kwargs)
#    1465                 if timeout:
# -> 1466                     resp = self._session.post(
#    1467                         url=url,
#
# c:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\arcgis\auth\api.py in post(self, url, data, json, **kwargs)
#     524             redirects = self.allow_redirects
# --> 525         return self._session.post(
#     526             url,
#
# c:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\requests\sessions.py in post(self, url, data, json, **kwargs)
#     636
# --> 637         return self.request("POST", url, data=data, json=json, **kwargs)
#     638
#
# c:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     588         send_kwargs.update(settings)
# --> 589         resp = self.send(prep, **send_kwargs)
#     590
#
# c:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     702         # Send the request
# --> 703         r = adapter.send(request, **kwargs)
#     704
#
# c:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     518
# --> 519             raise ConnectionError(e, request=request)
#     520
#
# ConnectionError: HTTPSConnectionPool(host='esriaiddev.maps.arcgis.com', port=443): Max retries exceeded with url: /sharing/rest/search (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000001CB5BBA09A0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5612\1073136248.py in <cell line: 23>()
#      22 image_count = 0
#      23 for acq_date_extent in unique_acq_dates_extent:
# ---> 24     download_image(gis, acq_date_extent[0], 256, acq_date_extent[1], output_dir)
#      25     image_count += 1
#      26     print(f"Downloaded {image_count} of {total_images} images. {total_images - image_count} images left.")
#
# ~\AppData\Local\Temp\ipykernel_5612\2570966918.py in download_image(gis, acq_date, max_pixels, extent, output_dir)
#     112 def download_image(gis, acq_date, max_pixels, extent, output_dir):
#     113
# --> 114     sentinel_item=gis.content.search('255af1ceee844d6da8ef8440c8f90d00', 'Imagery Layer', outside_org=True)[0]
#     115     s2_layer = sentinel_item.layers[0]
#     116
#
# c:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\arcgis\gis\__init__.py in search(self, query, item_type, sort_field, sort_order, max_items, outside_org, categories, category_filters, enrich)
#    7740             elif accountid:
#    7741                 query = "accountid:" + accountid
# -> 7742         itemlist = self.advanced_search(
#    7743             query=query,
#    7744             max_items=max_items,
#
# c:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\arcgis\gis\__init__.py in advanced_search(self, query, return_count, max_items, bbox, categories, category_filter, start, sort_field, sort_order, count_fields, count_size, as_dict, enrich)
#    7437             max_items = 0
#    7438         if max_items <= 100:
# -> 7439             res = _search(
#    7440                 gis=self._gis,
#    7441                 query=query,
#
# c:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\arcgis\gis\_impl\_search.py in _search(gis, query, stype, max_items, bbox, categories, category_filter, start, sort_field, sort_order, count_fields, count_size, group_id, as_dict, enrich)
#     161             url = "{base}community/groups".format(base=gis._portal.resturl)
#     162     count = 0
# --> 163     res = gis._con.post(url, params)
#     164     results = copy.deepcopy(res)
#     165     count += int(res["num"])
#
# c:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\lib\site-packages\arcgis\gis\_impl\_con\_connection.py in post(self, path, params, files, **kwargs)
#    1494             raise requests.exceptions.SSLError("Invalid URL provided: %s" % errIU)
#    1495         except requests.exceptions.ConnectionError as errCE:
# -> 1496             raise requests.exceptions.ConnectionError(
#    1497                 "A connection error has occurred: %s" % errCE
#    1498             )
#
# ConnectionError: A connection error has occurred: HTTPSConnectionPool(host='esriaiddev.maps.arcgis.com', port=443): Max retries exceeded with url: /sharing/rest/search (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000001CB5BBA09A0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
